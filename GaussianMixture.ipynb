# %%
from sklearn.datasets import make_blobs
from sklearn.mixture import GaussianMixture
import matplotlib.pyplot as plt

# %%
# dataset
X, y = make_blobs(n_samples=300, centers=3, random_state=42)

# %%
# model
model = GaussianMixture(n_components=3)

# %%
model.fit(X)
# Out:
# C:\Users\bhati\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1425: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# GaussianMixture(n_components=3)

# %%
labels = model.predict(X)

# %%
# visualization
plt.scatter(X[:,0], X[:,1], c=labels)
plt.title("Gaussian Mixture Model Clustering")
plt.xlabel("Feature 1")
plt.ylabel("Feature 2")
plt.show()
