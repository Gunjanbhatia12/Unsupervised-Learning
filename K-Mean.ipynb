# %%
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
# Dataset
X = np.array([
    [20, 30],
    [25, 35],
    [80, 85],
    [85, 90],
    [50, 60],
    [52, 58]
])

# Apply KMeans
kmeans = KMeans(n_clusters=2, random_state=0)
kmeans.fit(X)

# Get results
labels = kmeans.labels_
centroids = kmeans.cluster_centers_

print("Cluster Labels:", labels)
print("Centroids:", centroids)

# Visualization
plt.scatter(X[:,0], X[:,1], c=labels)
plt.scatter(centroids[:,0], centroids[:,1], marker='X', s=200)
plt.xlabel("Income")
plt.ylabel("Spending Score")
plt.show()
# Out:
# C:\Users\bhati\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1425: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Cluster Labels: [1 1 0 0 1 1]
# Centroids: [[82.5  87.5 ]
#  [36.75 45.75]]
